# %%
import pyvista as pv

# %%
mc1 = pv.read('/Users/maro/Library/CloudStorage/OneDrive-UniversityofLeeds/PhD-wrist/WorkPackages/WorkPackages/TMCJ-Contact/Computational/InpPipeline/outputs/testing/SML-1/inpFiles/50000R/mesh/0-0-0-mc1_positioned.vtu')
tpm = pv.read('/Users/maro/Library/CloudStorage/OneDrive-UniversityofLeeds/PhD-wrist/WorkPackages/WorkPackages/TMCJ-Contact/Computational/InpPipeline/outputs/testing/SML-1/inpFiles/50000R/mesh/0-0-0-tpm_neutral.vtu')

# %%
mc1.extract_cells_by_type(5).extract_surface(algorithm=None).plot_normals()
# Out:
# Widget(value='<iframe src="http://localhost:52410/index.html?ui=P_0x330563920_3&reconnect=auto" class="pyvista…
