# %%
import pyvista as pv

# %%
mc1 = pv.read('/Users/maro/Library/CloudStorage/OneDrive-UniversityofLeeds/PhD-wrist/WorkPackages/WorkPackages/TMCJ-Contact/Computational/InpPipeline/outputs/testing/test2/inpFiles/14548R/mesh/0-0-0-mc1_positioned.vtu')
tpm = pv.read('/Users/maro/Library/CloudStorage/OneDrive-UniversityofLeeds/PhD-wrist/WorkPackages/WorkPackages/TMCJ-Contact/Computational/InpPipeline/outputs/testing/test2/inpFiles/14548R/mesh/0-0-0-tpm_neutral.vtu')

tpm_shell = tpm.extract_cells_by_type(5)

# %%
tpm_shell.extract_cells(tpm_shell['region_id']!=-1).extract_surface(algorithm=None).plot_normals()
# Out:
# Widget(value='<iframe src="http://localhost:52689/index.html?ui=P_0x32e5bac90_3&reconnect=auto" class="pyvista…
