# %% [markdown]
# # Not currently directly supported by cgal by the looks of things
#  - Have to create c3t3 every time for some reason

# %%
import pyvista as pv

# %%
import subprocess
path_MeshPipeline_main = '../../../../MeshPipeline/main.py'
subprocess.run(["python", path_MeshPipeline_main])
# Out:
# Updating parameters.json
# 	Wrote /Users/maro/Library/CloudStorage/OneDrive-UniversityofLeeds/PhD-wrist/WorkPackages/WorkPackages/TMCJ-Contact/Computational/MeshPipeline/set_parameters/parameters.json
#
#
# Full parameter file saved to outputs/testing/params/full_params-3.json
#
# SUBJECT: 14548R
# 	BONES: tpm-mc1
# 		STEP: 2Dmesh
# 			RUN ID: -0
# 			Runtime: 1.540s - ok
# 		STEP: cartilage
# 			RUN ID: -0-0
# 			Runtime: 1.543s - ok
# 		STEP: 3Dmesh
# 			RUN ID: -0-0-0
# 			Runtime: 3.110s - error
# CompletedProcess(args=['python', '../../../../MeshPipeline/main.py'], returncode=0)

# %%
sub = '14548R'
bones = 'tpm-mc1'
mesh = pv.read(f'outputs/testing/meshes/{sub}/{bones}/3Dmesh/mesh-0-0-0.vtu')
